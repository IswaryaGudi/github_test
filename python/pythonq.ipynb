# %%
l=[9,0,67,0,8,8]
set(l)
# Out:
# {0, 8, 9, 67}

# %%
s={89,90,6,'p',567,4556,9,(8,9),{9}}
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 s={89,90,6,'p',567,4556,9,(8,9),{9}}
#       2 s
#
# TypeError: unhashable type: 'set'

# %%
s={2,4,1}
s.add(8)
s
# Out:
# {1, 2, 4, 8}

# %%
s={2,4,1}
s.add((9,8))
s
# Out:
# {(9, 8), 1, 2, 4}

# %%
s={2,4,1}
s.update([9,8])
s
# Out:
# {1, 2, 4, 8, 9}

# %%
s={1, 2, 4, 8, 9}
s.remove(4)
s
# Out:
# {1, 2, 8, 9}

# %%
s={1, 2, 4, 8, 9}          #if the element is not there in set it gives error when we use remove() but it doesnt give error when we use discard
s.remove(40)
s
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 s={1, 2, 4, 8, 9}
# ----> 2 s.remove(40)
#       3 s
#
# KeyError: 40

# %%
s={1, 2, 4, 8, 9}
s.discard(4)
s
# Out:
# {1, 2, 8, 9}

# %%
s={1, 2, 4, 8, 9}
s.discard(40)
s
# Out:
# {1, 2, 4, 8, 9}

# %%
s={1, 2, 4, 8, 9}
s.pop()
s
# Out:
# {2, 4, 8, 9}

# %%
l=[1,2,3,4,5]
l.pop(0)
l
# Out:
# [2, 3, 4, 5]
